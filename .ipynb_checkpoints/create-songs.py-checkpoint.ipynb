# %%
import csv
from random import seed
from random import randint
import random



SONG_NAMES = ["Sweet  guide",
"festivity Sky",
"more Jam",
"Ain't My chost",
"mystical Surprise",
"mystical Surprise 2",
"Flowers For Spirit",
"a story about Nightmare",
"automatic Childhood",
"luxuriate July",
"cold Memories",
"unique heartache",
"be calm with Gift",
"spring train",
"nirvana Legend",
"repose Love",
"big Dream",
"Belong To Limit",
"Is this soul",
"Cool for the Moves",
"Is this Images",
"instrumental house",
"loaf Whispers",
"WILD power",
"what about Gamble",
"colors of move",
"A modern electronic September",
"Mysterious wolf",
"into yesterday",
"heavy ballad",
"next stars",
"breather Style",
"space for control",
"accoustic Midnight",
"come around with Sunset",
"Flowers For sun",
"Chains Of ballad",
"THAT'S lights",
"lone Tears",
"Interstellar World",
"golden Voice",
"quiet relaxation",
"Perfect Grooves",
"Tropical midnight",
"flowers in Affair",
"super Gamble",
"Quiet feelings",
"Running crash",
"forever Machine",
"golden Parranda"
]

GENRES = [
    'Hip-Hop',
    'Dance',
    'Accoustic',
    'Rap',
    'Surf'
]

ARTISTS = [
    'Guns N Roses',
    'Red Hot Chilli Peppers',
    'The Killers',
    'Fall Out Boy',
    'Shakira',
    'Bastille',
    'ACDC',
    'Kiss',
    'The Script',
    'The Strokes',
    'Dio',
    'David Bowie',
    'OneRepublic',
    'Malvadao',
    'Anita',
    'Green Day',
    'Weezer',
    'Roberto Carlos'

]


file_header = ['ID','Song','Genre', 'Artist']

with open('possible-songs.csv', 'w', encoding='UTF8', newline='') as file:
    i = 1
    seed(1)

    writer = csv.writer(file)
    
    writer.writerow(file_header)
    
    for song in SONG_NAMES:
        if i >= len(SONG_NAMES):
            break

        id = i    
        song = SONG_NAMES[i]
        artist = random.choice(ARTISTS)
        genre = random.choice(GENRES)

        row = [id,song,artist,genre]
        
        writer.writerow(row)
        
        i = i+1
